# %%
import os
import pandas as pd
from pathlib import Path

if not "root" in locals():
    current_path = Path(os.getcwd())
    root = current_path.parent.absolute()
    
os.chdir(root)
from data_treatment.box_creator import create_binary_box

df = pd.read_csv('database.csv')
df = create_binary_box(df, threshold=2., box_length=7)

# %%
hihih flemme
# Out:
#             Date  PX_OPEN_VIX_volatility  PX_HIGH_VIX_volatility  \
# 0     2000-01-03                   24.36                   26.15
# 1     2000-01-04                   24.94                   27.18
# 2     2000-01-05                   27.98                   29.00
# 3     2000-01-06                   26.68                   26.71
# 4     2000-01-07                   25.14                   25.17
# ...          ...                     ...                     ...
# 5377  2021-05-18                   18.89                   21.45
# 5378  2021-05-19                   22.46                   25.96
# 5379  2021-05-20                   22.33                   23.50
# 5380  2021-05-21                   20.42                   20.89
# 5381  2021-05-24                   20.50                   20.51
#
#       PX_LOW_VIX_volatility  PX_LAST_VIX_volatility  \
# 0                     23.98                   24.21
# 1                     24.80                   27.01
# 2                     25.85                   26.41
# 3                     24.70                   25.73
# 4                     21.72                   21.72
# ...                     ...                     ...
# 5377                  18.81                   21.34
# 5378                  21.88                   22.18
# 5379                  20.19                   20.67
# 5380                  19.53                   20.15
# 5381                  18.38                   18.40
#
#       VOLUME_TOTAL_CALL_VIX_volatility  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 5377                          435445.0
# 5378                          417537.0
# 5379                          208977.0
# 5380                          127120.0
# 5381                          268111.0
#
#       PUT_CALL_VOLUME_RATIO_CUR_DAY_VIX_volatility  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 5377                                        0.8205
# 5378                                        1.2020
# 5379                                        0.8944
# 5380                                        1.3804
# 5381                                        0.6661
#
#       VOLUME_TOTAL_PUT_VIX_volatility  TOT_OPT_VOLUME_CUR_DAY_VIX_volatility  \
# 0                                 NaN                                    NaN
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 4                                 NaN                                    NaN
# ...                               ...                                    ...
# 5377                         357293.0                               792738.0
# 5378                         501893.0                               919430.0
# 5379                         186913.0                               395890.0
# 5380                         175475.0                               302595.0
# 5381                         178591.0                               446702.0
#
#       OPEN_INT_TOTAL_CALL_VIX_volatility  ...  S&P 500 Weekly Close_SENTIMENT  \
# 0                                    NaN  ...                         1469.25
# 1                                    NaN  ...                         1469.25
# 2                                    NaN  ...                         1469.25
# 3                                    NaN  ...                         1441.47
# 4                                    NaN  ...                         1441.47
# ...                                  ...  ...                             ...
# 5377                           6190495.0  ...                         4063.04
# 5378                           4725251.0  ...                         4063.04
# 5379                           4842985.0  ...                         4137.60
# 5380                           4884139.0  ...                         4137.60
# 5381                           4910844.0  ...                         4137.60
#
#       ST_Rev_F-F_ST_Reversal_Factor_daily  \
# 0                                    0.69
# 1                                    1.62
# 2                                    1.11
# 3                                    0.76
# 4                                   -0.72
# ...                                   ...
# 5377                                 1.13
# 5378                                 1.02
# 5379                                 1.24
# 5380                                -0.76
# 5381                                 0.59
#
#       Mkt-RF_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                            -0.71
# 1                                            -4.06
# 2                                            -0.09
# 3                                            -0.73
# 4                                             3.21
# ...                                            ...
# 5377                                         -0.69
# 5378                                         -0.34
# 5379                                          1.15
# 5380                                         -0.04
# 5381                                          0.99
#
#       SMB_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                         -0.06
# 1                                          0.33
# 2                                          0.33
# 3                                         -0.05
# 4                                         -0.94
# ...                                         ...
# 5377                                       0.06
# 5378                                      -0.49
# 5379                                      -0.47
# 5380                                       0.44
# 5381                                      -0.48
#
#       HML_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                         -1.42
# 1                                          2.07
# 2                                          0.16
# 3                                          1.26
# 4                                         -1.43
# ...                                         ...
# 5377                                      -0.93
# 5378                                      -0.46
# 5379                                      -1.43
# 5380                                       0.98
# 5381                                      -0.69
#
#       RMW_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                         -1.50
# 1                                          0.47
# 2                                          0.41
# 3                                          0.65
# 4                                         -0.88
# ...                                         ...
# 5377                                      -1.01
# 5378                                      -0.18
# 5379                                      -0.84
# 5380                                      -0.12
# 5381                                       0.25
#
#       CMA_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                         -0.63
# 1                                          1.45
# 2                                          1.11
# 3                                          1.22
# 4                                         -0.95
# ...                                         ...
# 5377                                      -0.42
# 5378                                      -0.34
# 5379                                      -0.49
# 5380                                      -0.06
# 5381                                      -0.30
#
#       RF_F-F_Research_Data_5_Factors_2x3_daily  \
# 0                                        0.021
# 1                                        0.021
# 2                                        0.021
# 3                                        0.021
# 4                                        0.021
# ...                                        ...
# 5377                                     0.000
# 5378                                     0.000
# 5379                                     0.000
# 5380                                     0.000
# 5381                                     0.000
#
#       Mom   _F-F_Momentum_Factor_daily  Box
# 0                                -0.08    0
# 1                                -1.91    0
# 2                                -0.49    0
# 3                                -1.49    0
# 4                                 0.56    1
# ...                                ...  ...
# 5377                             -0.26    1
# 5378                             -0.70    1
# 5379                              0.20    1
# 5380                              0.25    1
# 5381                              1.11    0
#
# [5382 rows x 166 columns]
